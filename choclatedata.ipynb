# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_excel("/content/telugu-dashboard-blank.xlsx")

# %%
data1.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1 Excel Dashboard           Unnamed: 3  \
# 0         NaN         NaN             NaN                  NaN
# 1         NaN         NaN             NaN                  NaN
# 2         NaN         NaN         Country              Product
# 3         NaN         NaN       Australia         Almond Choco
# 4         NaN         NaN       Australia        85% Dark Bars
# 5         NaN         NaN              UK         Orange Choco
# 6         NaN         NaN           India   Smooth Sliky Salty
# 7         NaN         NaN             USA  Peanut Butter Cubes
# 8         NaN         NaN       Australia     Fruit & Nut Bars
# 9         NaN         NaN       Australia     Fruit & Nut Bars
#
#                  Unnamed: 4           Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                       NaN                  NaN        NaN        NaN
# 1                       NaN                  NaN        NaN        NaN
# ...

# %%
data1.info()
data1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1803 entries, 0 to 1802
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       0 non-null      float64
#  1   Unnamed: 1       0 non-null      float64
#  2   Excel Dashboard  1801 non-null   object
#  3   Unnamed: 3       1801 non-null   object
#  4   Unnamed: 4       1801 non-null   object
#  5   Unnamed: 5       1801 non-null   object
#  6   Unnamed: 6       1801 non-null   object
#  7   Unnamed: 7       1801 non-null   object
#  8   Unnamed: 8       1801 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 126.9+ KB
# (1803, 9)

# %%
data1.isna().sum()
# Out:
# Unnamed: 0         1803
# Unnamed: 1         1803
# Excel Dashboard       2
# Unnamed: 3            2
# Unnamed: 4            2
# Unnamed: 5            2
# Unnamed: 6            2
# Unnamed: 7            2
# Unnamed: 8            2
# dtype: int64

# %%
data2=data1.drop(["Unnamed: 1","Unnamed: 0"],axis=1)
data2.head(10)
# Out:
#   Excel Dashboard           Unnamed: 3                Unnamed: 4  \
# 0             NaN                  NaN                       NaN
# 1             NaN                  NaN                       NaN
# 2         Country              Product              Sales Person
# 3       Australia         Almond Choco      Ramalingam Kothapeta
# 4       Australia        85% Dark Bars     Devsena Veluvalapalli
# 5              UK         Orange Choco     Devsena Veluvalapalli
# 6           India   Smooth Sliky Salty   Parasuramudu Jamakayala
# 7             USA  Peanut Butter Cubes  Sreenivasa Naik Gudiwada
# 8       Australia     Fruit & Nut Bars      Ramalingam Kothapeta
# 9       Australia     Fruit & Nut Bars      Nazeer Basha Mustafa
#
#             Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0                  NaN        NaN        NaN        NaN
# 1                  NaN        NaN        NaN        NaN
# 2                 Date     Amount      Boxes   Category
# ...

# %%
data3=data2.rename({"Excel Dashboard":"Country", "Unnamed: 3":"Product","Unnamed: 4":"SalesPerson","Unnamed: 5":"Date","Unnamed: 6": "Amount","Unnamed: 7": "Boxes","Unnamed: 8":"Category"},axis=1)
data3.head(10)
# Out:
#      Country              Product               SalesPerson  \
# 0        NaN                  NaN                       NaN
# 1        NaN                  NaN                       NaN
# 2    Country              Product              Sales Person
# 3  Australia         Almond Choco      Ramalingam Kothapeta
# 4  Australia        85% Dark Bars     Devsena Veluvalapalli
# 5         UK         Orange Choco     Devsena Veluvalapalli
# 6      India   Smooth Sliky Salty   Parasuramudu Jamakayala
# 7        USA  Peanut Butter Cubes  Sreenivasa Naik Gudiwada
# 8  Australia     Fruit & Nut Bars      Ramalingam Kothapeta
# 9  Australia     Fruit & Nut Bars      Nazeer Basha Mustafa
#
#                   Date     Amount  Boxes  Category
# 0                  NaN        NaN    NaN       NaN
# 1                  NaN        NaN    NaN       NaN
# 2                 Date     Amount  Boxes  Category
# 3  2023-01-26 00:00:00    70422.8     47      Bars
# ...

# %%
data3.dropna()
# Out:
#         Country              Product              SalesPerson  \
# 2       Country              Product             Sales Person
# 3     Australia         Almond Choco     Ramalingam Kothapeta
# 4     Australia        85% Dark Bars    Devsena Veluvalapalli
# 5            UK         Orange Choco    Devsena Veluvalapalli
# 6         India   Smooth Sliky Salty  Parasuramudu Jamakayala
# ...         ...                  ...                      ...
# 1798     Canada  Spicy Special Slims     Nazeer Basha Mustafa
# 1799  Australia              Eclairs            Mayur Kousika
# 1800     Canada      Raspberry Choco     Nazeer Basha Mustafa
# 1801         UK   Smooth Sliky Salty    Yedukondalu Panditula
# 1802        USA       70% Dark Bites            Gopal Venkata
#
#                      Date     Amount  Boxes  Category
# 2                    Date     Amount  Boxes  Category
# 3     2023-01-26 00:00:00    70422.8     47      Bars
# 4     2023-08-08 00:00:00   670862.5   1094      Bars
# ...

# %%
data4=data3.drop(2)

# %%
data4.head(10)
# Out:
#       Country              Product               SalesPerson  \
# 0         NaN                  NaN                       NaN
# 1         NaN                  NaN                       NaN
# 3   Australia         Almond Choco      Ramalingam Kothapeta
# 4   Australia        85% Dark Bars     Devsena Veluvalapalli
# 5          UK         Orange Choco     Devsena Veluvalapalli
# 6       India   Smooth Sliky Salty   Parasuramudu Jamakayala
# 7         USA  Peanut Butter Cubes  Sreenivasa Naik Gudiwada
# 8   Australia     Fruit & Nut Bars      Ramalingam Kothapeta
# 9   Australia     Fruit & Nut Bars      Nazeer Basha Mustafa
# 10        USA         Almond Choco         Sravanthi Chalaki
#
#                    Date     Amount Boxes Category
# 0                   NaN        NaN   NaN      NaN
# 1                   NaN        NaN   NaN      NaN
# 3   2023-01-26 00:00:00    70422.8    47     Bars
# 4   2023-08-08 00:00:00   670862.5  1094     Bars
# ...

# %%
data4.dropna()
# Out:
#         Country              Product               SalesPerson  \
# 3     Australia         Almond Choco      Ramalingam Kothapeta
# 4     Australia        85% Dark Bars     Devsena Veluvalapalli
# 5            UK         Orange Choco     Devsena Veluvalapalli
# 6         India   Smooth Sliky Salty   Parasuramudu Jamakayala
# 7           USA  Peanut Butter Cubes  Sreenivasa Naik Gudiwada
# ...         ...                  ...                       ...
# 1798     Canada  Spicy Special Slims      Nazeer Basha Mustafa
# 1799  Australia              Eclairs             Mayur Kousika
# 1800     Canada      Raspberry Choco      Nazeer Basha Mustafa
# 1801         UK   Smooth Sliky Salty     Yedukondalu Panditula
# 1802        USA       70% Dark Bites             Gopal Venkata
#
#                      Date     Amount Boxes Category
# 3     2023-01-26 00:00:00    70422.8    47     Bars
# 4     2023-08-08 00:00:00   670862.5  1094     Bars
# ...

# %%
data5=data4.dropna()
data5.head(10)
# Out:
#       Country              Product               SalesPerson  \
# 3   Australia         Almond Choco      Ramalingam Kothapeta
# 4   Australia        85% Dark Bars     Devsena Veluvalapalli
# 5          UK         Orange Choco     Devsena Veluvalapalli
# 6       India   Smooth Sliky Salty   Parasuramudu Jamakayala
# 7         USA  Peanut Butter Cubes  Sreenivasa Naik Gudiwada
# 8   Australia     Fruit & Nut Bars      Ramalingam Kothapeta
# 9   Australia     Fruit & Nut Bars      Nazeer Basha Mustafa
# 10        USA         Almond Choco         Sravanthi Chalaki
# 11     Canada        Drinking Coco     Yedukondalu Panditula
# 12  Australia      Raspberry Choco              Duran Appala
#
#                    Date     Amount Boxes Category
# 3   2023-01-26 00:00:00    70422.8    47     Bars
# 4   2023-08-08 00:00:00   670862.5  1094     Bars
# 5   2023-05-23 00:00:00  171422.16   199     Bars
# 6   2023-02-02 00:00:00  514083.57   588     Bars
# ...

# %%
data5['Data_format'] = pd.to_datetime(data5['Date'])
data6=data5.drop(["Date"],axis=1)
data6.head(10)
# Out:
# <ipython-input-15-0eb41f9cb898>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5['Data_format'] = pd.to_datetime(data5['Date'])
#       Country              Product               SalesPerson     Amount Boxes  \
# 3   Australia         Almond Choco      Ramalingam Kothapeta    70422.8    47
# 4   Australia        85% Dark Bars     Devsena Veluvalapalli   670862.5  1094
# 5          UK         Orange Choco     Devsena Veluvalapalli  171422.16   199
# 6       India   Smooth Sliky Salty   Parasuramudu Jamakayala  514083.57   588
# 7         USA  Peanut Butter Cubes  Sreenivasa Naik Gudiwada   479902.5   330
# 8   Australia     Fruit & Nut Bars      Ramalingam Kothapeta   816698.4   984
# ...

# %%
filename="choclatedata1.xlsx"
data6.to_excel(filename)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.array([0,6])
Y=np.array([0,100])

# %%
plt.plot(X,Y)
plt.show()

# %%
points=np.array([4,7,10,3,12,2,15,25,90,55,77])
plt.plot(points)
plt.show()

# %%
points=np.array([50,35,15,77])
plt.pie(points)
plt.show()
